Jenkins File Read Vulnerability - CVE-2024-23897  2024-10-01T08:13:10Z
# 42  Creating a synchronized store between main and...  2024-10-01T09:58:24Z
# 43  MongoDB made simple: a basic guide to get started  2024-10-01T09:52:58Z
# 44                         What are Closures in Rust?  2024-10-01T06:30:02Z
# 45      The Best Tools for Building CRUD Applications  2024-10-01T09:36:05Z
# 46  LabEx Trending: Implementing React Navigation ...  2024-10-01T09:32:58Z
# 47  How Does Angular SEO Work and Why Is It Import...  2024-10-01T09:34:08Z
# 48  Golang microservice modular architecture with ...  2024-10-01T09:22:27Z
# 49            Locking Mechanisms in High-Load Systems  2024-10-01T11:00:00Z
#
#                          Author  \
# 0                   Ben Halpern
# 1   Ingo Steinke, web developer
# 2                    Ayu Adiati
# 3                    Nevo David
# 4                  Abbey Perini
# 5                      Rob Race
# 6                   Jaime López
# 7            Hugo Ramon Pereira
# 8              Arindam Majumder
# 9              Asjad Ahmed Khan
# 10                   Astrodevil
# 11               Ibrahim Salami
# 12                    balrajOla
# 13               Matti Bar-Zeev
# 14       Otutu Chinedu Kingsley
# 15                    Vishwas R
# 16                mohamed Tayel
# 17                   Se-ok Jeon
# 18                   Se-ok Jeon
# 19                    Alex Roor
# 20               Sharon Yelenik
# 21                 Ramon Gebben
# 22               Daniel Azevedo
# 23                Nazneen Ahmad
# 24                 Jorjis Hasan
# 25                   EmreKanbay
# 26                  Ivan Djuric
# 27                    Rajon Dey
# 28                Kedjuprecious
# 29                  Kiregi Paul
# 30                  Michael Otu
# 31             محمد يزيد الصبري
# 32           Bellatreche Brahim
# 33           El Morjani Mohamed
# 34                        Lymah
# 35                        Geoff
# 36                Parnika-Gupta
# 37                 Romar Cablao
# 38                Steve Wortham
# 39               Sheraz Manzoor
# 40                    Ali Ahsan
# 41               Very Lazy Tech
# 42               T Sudhish Nair
# 43              mahugnon dousso
# 44             Francesco Ciulla
# 45                        SCAND
# 46                        Labby
# 47                        Parth
# 48                         Anze
# 49                  luminousmen
#
#                                                  Tags Reading Time  \
# 0                          #discuss#watercooler#jokes   1 min read
# 1                             #discuss#watercooler#ai   6 min read
# 2                           #opensource#hacktoberfest   6 min read
# 3             #webdev#javascript#programming#tutorial   4 min read
# 4                #techtalks#career#programming#devrel   5 min read
# 5                                 #rails#ruby#hotwire  13 min read
# 6               #microsoftgraph#powershell#sharepoint   8 min read
# 7                             #clerk#vue#react#nextjs   6 min read
# 8   #opensource#webdev#beginners#hacktoberfestchal...   7 min read
# 9                          #go#ethereum#cosmosdb#web3   5 min read
# 10                    #webdev#opensource#ai#beginners  13 min read
# 11                           #devops#sre#productivity  10 min read
# 12                   #java#webdev#learning#javascript   3 min read
# 13                                #webdev#html#coding   7 min read
# 14                  #webdev#laravel#netsuite#tutorial   8 min read
# 15             #canvasjs#datatables#javascript#charts   3 min read
# 16                #csharp#dotnet#programming#tutorial   4 min read
# 17                                                      1 min read
# 18                                                      1 min read
# 19        #webdev#programming#productivity#blockchain   3 min read
# 20     #wordpress#mediamanagement#medialibrary#webdev   5 min read
# 21                 #javascript#typescript#gamedev#dnd   2 min read
# 22                                                      4 min read
# 23  #testscenario#testscript#softwaretesting#testp...  16 min read
# 24                           #vite#jest#testing#react   4 min read
# 25                                                      2 min read
# 26                                                      8 min read
# 27  #7usefuljsprojects#vanillajs#javascript#jsproj...   3 min read
# 28           #beginners#javascript#geminiapi#learning  22 min read
# 29                                                      3 min read
# 30                     #javascript#api#beginners#node   9 min read
# 31             #middleware#routing#controller#laravel   4 min read
# 32                                                      1 min read
# 33                                    #devops#aws#cli   2 min read
# 34             #opensource#starsearch#contribution#ai   3 min read
# 35                           #webdev#html#website#web   2 min read
# 36                 #webdev#javascript#react#beginners   3 min read
# 37                     #aws#karpenter#awscommunityday   2 min read
# 38                   #testing#software#ai#programming  10 min read
# 39               #nextjs#webdev#typescript#javascript   3 min read
# 40                      #angular#react#vue#javascript   3 min read
# 41     #cybersecurity#exploit#vulnerabilities#jenkins   2 min read
# 42            #electron#javascript#webdev#programming   1 min read
# 43                      #database#datascience#mongodb   1 min read
# 44                #programming#opensource#rust#webdev   1 min read
# 45                          #crudapp#crudapps#webapps   5 min read
# 46                        #labex#programming#projects   2 min read
# 47                      #seo#angular#digitalmarketing   4 min read
# 48                                #webdev#go#tutorial   3 min read
# 49                 #concurrency#database#architecture   4 min read
#
#                                       Article Content
# 0   Meme Monday! Today's cover image comes from . ...
# 1   "Future workshop with AI," "creativity with AI...
# 2   It's that time of the year again: Hacktoberfes...
# 3   According to npmjs.com statistics, i18next is ...
# 4   Take it from someone who barely passed their c...
# 5   This article will explore Turbo 8's powerful f...
# 6   Are you tired of the limitations of PowerShell...
# 7   INTRODUCTION Authentication is a very importan...
# 8   October is Almost Here—And So Are Some Epic Op...
# 9   The blockchain ecosystem has rapidly evolved, ...
# 10  AI is flipping the script on software developm...
# 11  Ensuring efficient, reliable, high-quality sof...
# 12  GraalVM is an advanced JIT (Just-In-Time) comp...
# 13  What is the best basic template for an HTML do...
# 14  NetSuite offers various methods for authentica...
# 15   is a JavaScript charting library that allows ...
# 16  Meta Description: Learn about the power of col...
# 17  Input: head = [1,2,3,4,5]\nOutput: [5,4,3,2,1]...
# 18  Input: head = [1,2,3,4,5]\nOutput: [5,4,3,2,1]...
# 19  In the world of blockchain development, scalab...
# 20  Managing media on a WordPress site can quickly...
# 21  As a passionate Dungeons & Dragons player and ...
# 22  Hi devs, If you're new to Docker and trying to...
# 23  Test scripts are a set of instructions or proc...
# 24  "You should write tests before you write the c...
# 25  This blog post is firstly published on my pers...
# 26  Email workflow automation takes over administr...
# 27  As a modern-age web developer, JavaScript is a...
# 28  A chatbot is a type of software that mimics co...
# 29  Structured Query Language\nIntroduction to SQL...
# 30  Previously in , we started with some javascrip...
# 31  Bismillaahirrahmaanirrahiim. Pernahkah kamu pe...
# 32  There is no need to write code for it. Yii alr...
# 33  Managing access control for your Amazon S3 buc...
# 34  OpenSauced is a company on a mission to empowe...
# 35  If you have a static website (e.g., built with...
# 36  Once upon a time in the vibrant land of Reacto...
# 37  This blog post summarizes my presentation deli...
# 38  Smoke testing made the job easy for many teste...
# 39  Let's talk about routing in Nextjs. Today, we ...
# 40  When deciding which frontend framework to use,...
# 41   is a critical vulnerability in Jenkins that a...
# 42  Check out our latest blog on Creating a Synchr...
# 43  🚀 Ready to dive into the world of databases? 🚀...
# 44  What are Closures in Rust? A closure in Rust i...
# 45  CRUD web apps, which let you Create, Read, Upd...
# 46  Dive into the latest and greatest projects fro...
# 47  In today’s competitive digital world, optimizi...
# 48  Golang shines in backend development, concurre...
# 49  In the world of concurrent systems, especially...

# %% [markdown]
# ## Getting the Word Count, Sentiment and Polarity Score of the Article Content

# %%
from nltk.corpus import stopwords
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

df = merged_df
# Download the stopwords dataset
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')


def count_words_without_stopwords(text):
    if isinstance(text, (str, bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        return len(filtered_words)
    else:
        0

df['Word Count'] = df['Article Content'].apply(count_words_without_stopwords)


sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    sentiment_scores = sid.polarity_scores(row)
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
        sentiment = 'Positive'
    elif compound_score <= -0.05:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'

    return sentiment, compound_score

df[['Sentiment', 'Compound Score']] = df['Article Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))

df
# Out:
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                                  Link  \
# 0                 https://dev.to/ben/meme-monday-20jg
# 1   https://dev.to/ingosteinke/why-ai-is-the-new-s...
# 2   https://dev.to/virtualcoffee/hacktoberfest-202...
# 3       https://dev.to/nevodavid/dont-use-i18next-n1a
# 4   https://dev.to/abbeyperini/so-you-need-to-give...
# 5   https://dev.to/rob__race/leveraging-turbo-8-be...
# 6   https://dev.to/jaloplo/automating-sharepoint-e...
# 7   https://dev.to/hramonpereira/how-to-manage-use...
# 8   https://dev.to/arindam_1729/7-open-source-even...
# 9   https://dev.to
 AI Assistants for Frontend Developers That ...  2024-10-01T07:00:00Z
# 11  How to improve DORA metrics as a release engineer  2024-10-01T11:03:23Z
# 12  Exploring GraalVM: How to Speed Up Java Applic...  2024-10-01T11:37:12Z
# 13                Back to sq1: My basic HTML template  2024-10-01T10:00:00Z
# 14  How to set up NetSuite Token-based Authenticat...  2024-10-01T11:18:17Z
# 15               Integrating CanvasJS with DataTables  2024-10-01T11:38:23Z
# 16     Mastering C# Fundamentals: Understanding Lists  2024-10-01T11:32:51Z
# 17                           206. reverse-linked-list  2024-10-01T11:33:07Z
# 18                           206. reverse-linked-list  2024-10-01T11:33:08Z
# 19  Unlocking Ethereum’s Full Potential with Eigen...  2024-10-01T11:34:50Z
# 20  Boost Your WordPress Media Management with Clo...  2024-10-01T11:14:03Z
# 21  Building a Custom Stream Deck for My D&D Table...  2024-10-01T11:16:20Z
# 22   Installing Docker on Windows: A Beginner’s Guide  2024-10-01T11:20:10Z
# 23  TestScript: Detailed Guide With Templates And ...  2024-10-01T11:20:17Z
# 24                       🧪 Setup Jest (Webpack, Vite)  2024-10-01T11:21:57Z
# 25   Regex Cheat Sheet - Regular Expressions Tutorial  2024-10-01T11:26:01Z
# 26  Email Workflow Automation 101: Templates, Tool...  2024-10-01T10:57:09Z
# 27         7 Useful Vanilla JS Projects for Practice!  2024-10-01T11:05:49Z
# 28  Creating an Information Bot: A Beginner's Guid...  2024-10-01T11:09:22Z
# 29          Introduction to Structured Query Language  2024-10-01T10:42:07Z
# 30                      JavaScript Essentials: Part 2  2024-10-01T10:53:00Z
# 31  🗺️ Peta Jalan Laravel: Menjelajah Routing, Mid...  2024-10-01T10:40:36Z
# 32  Answer: Sorting data in default rest api - Yii...  2024-10-01T10:26:51Z
# 33      How to Apply S3 Bucket Policies Using AWS CLI  2024-10-01T10:24:16Z
# 34  How StarSearch Makes Open Source Collaboration...  2024-10-01T10:34:55Z
# 35                               Static website forms  2024-10-01T10:35:11Z
# 36  React Meets Disney: Unveiling the Magic of Hoo...  2024-10-01T04:40:01Z
# 37  Scaling & Optimizing Kubernetes with Karpenter...  2024-10-01T10:06:13Z
# 38  The Most Comprehensive and Friendly Guide On S...  2024-10-01T10:19:44Z
# 39  Introduction to Next.js Middleware: How It Wor...  2024-10-01T10:13:13Z
# 40  Angular vs. React vs. Vue: Which is the Best F...  2024-10-01T10:17:21Z
# 41   Jenkins File Read Vulnerability - CVE-2024-23897  2024-10-01T08:13:10Z
# 42  Creating a synchronized store between main and...  2024-10-01T09:58:24Z
# 43  MongoDB made simple: a basic guide to get started  2024-10-01T09:52:58Z
# 44                         What are Closures in Rust?  2024-10-01T06:30:02Z
# 45      The Best Tools for Building CRUD Applications  2024-10-01T09:36:05Z
# 46  LabEx Trending: Implementing React Navigation ...  2024-10-01T09:32:58Z
# 47  How Does Angular SEO Work and Why Is It Import...  2024-10-01T09:34:08Z
# 48  Golang microservice modular architecture with ...  2024-10-01T09:22:27Z
# 49            Locking Mechanisms in High-Load Systems  2024-10-01T11:00:00Z
#
#                          Author  \
# 0                   Ben Halpern
# 1   Ingo Steinke, web developer
# 2                    Ayu Adiati
# 3                    Nevo David
# 4                  Abbey Perini
# 5                      Rob Race
# 6                   Jaime López
# 7            Hugo Ramon Pereira
# 8              Arindam Majumder
# 9              Asjad Ahmed Khan
# 10                   Astrodevil
# 11               Ibrahim Salami
# 12                    balrajOla
# 13               Matti Bar-Zeev
# 14       Otutu Chinedu Kingsley
# 15                    Vishwas R
# 16                mohamed Tayel
# 17                   Se-ok Jeon
# 18                   Se-ok Jeon
# 19                    Alex Roor
# 20               Sharon Yelenik
# 21                 Ramon Gebben
# 22               Daniel Azevedo
# 23                Nazneen Ahmad
# 24                 Jorjis Hasan
# 25                   EmreKanbay
# 26                  Ivan Djuric
# 27                    Rajon Dey
# 28                Kedjuprecious
# 29                  Kiregi Paul
# 30                  Michael Otu
# 31             محمد يزيد الصبري
# 32           Bellatreche Brahim
# 33           El Morjani Mohamed
# 34                        Lymah
# 35                        Geoff
# 36                Parnika-Gupta
# 37                 Romar Cablao
# 38                Steve Wortham
# 39               Sheraz Manzoor
# 40                    Ali Ahsan
# 41               Very Lazy Tech
# 42               T Sudhish Nair
# 43              mahugnon dousso
# 44             Francesco Ciulla
# 45                        SCAND
# 46                        Labby
# 47                        Parth
# 48                         Anze
# 49                  luminousmen
#
#                                                  Tags Reading Time  \
# 0                          #discuss#watercooler#jokes   1 min read
# 1                             #discuss#watercooler#ai   6 min read
# 2                           #opensource#hacktoberfest   6 min read
# 3             #webdev#javascript#programming#tutorial   4 min read
# 4                #techtalks#career#programming#devrel   5 min read
# 5                                 #rails#ruby#hotwire  13 min read
# 6               #microsoftgraph#powershell#sharepoint   8 min read
# 7                             #clerk#vue#react#nextjs   6 min read
# 8   #opensource#webdev#beginners#hacktoberfestchal...   7 min read
# 9                          #go#ethereum#cosmosdb#web3   5 min read
# 10                    #webdev#opensource#ai#beginners  13 min read
# 11                           #devops#sre#productivity  10 min read
# 12                   #java#webdev#learning#javascript   3 min read
# 13                                #webdev#html#coding   7 min read
# 14                  #webdev#laravel#netsuite#tutorial   8 min read
# 15             #canvasjs#datatables#javascript#charts   3 min read
# 16                #csharp#dotnet#programming#tutorial   4 min read
# 17                                                      1 min read
# 18                                                      1 min read
# 19        #webdev#programming#productivity#blockchain   3 min read
# 20     #wordpress#mediamanagement#medialibrary#webdev   5 min read
# 21                 #javascript#typescript#gamedev#dnd   2 min read
# 22                                                      4 min read
# 23  #testscenario#testscript#softwaretesting#testp...  16 min read
# 24                           #vite#jest#testing#react   4 min read
# 25                                                      2 min read
# 26                                                      8 min read
# 27  #7usefuljsprojects#vanillajs#javascript#jsproj...   3 min read
# 28           #beginners#javascript#geminiapi#learning  22 min read
# 29                                                      3 min read
# 30                     #javascript#api#beginners#node   9 min read
# 31             #middleware#routing#controller#laravel   4 min read
# 32                                                      1 min read
# 33                                    #devops#aws#cli   2 min read
# 34             #opensource#starsearch#contribution#ai   3 min read
# 35                           #webdev#html#website#web   2 min read
# 36                 #webdev#javascript#react#beginners   3 min read
# 37                     #aws#karpenter#awscommunityday   2 min read
# 38                   #testing#software#ai#programming  10 min read
# 39               #nextjs#webdev#typescript#javascript   3 min read
# 40                      #angular#react#vue#javascript   3 min read
# 41     #cybersecurity#exploit#vulnerabilities#jenkins   2 min read
# 42            #electron#javascript#webdev#programming   1 min read
# 43                      #database#datascience#mongodb   1 min read
# 44                #programming#opensource#rust#webdev   1 min read
# 45                          #crudapp#crudapps#webapps   5 min read
# 46                        #labex#programming#projects   2 min read
# 47                      #seo#angular#digitalmarketing   4 min read
# 48                                #webdev#go#tutorial   3 min read
# 49                 #concurrency#database#architecture   4 min read
#
#                                       Article Content  Word Count Sentiment  \
# 0   Meme Monday! Today's cover image comes from . ...          19  Negative
# 1   "Future workshop with AI," "creativity with AI...         782  Negative
# 2   It's that time of the year again: Hacktoberfes...         432  Positive
# 3   According to npmjs.com statistics, i18next is ...         538  Positive
# 4   Take it from someone who barely passed their c...         739  Positive
# 5   This article will explore Turbo 8's powerful f...        1338  Positive
# 6   Are you tired of the limitations of PowerShell...         697  Positive
# 7   INTRODUCTION Authentication is a very importan...         595  Positive
# 8   October is Almost Here—And So Are Some Epic Op...         929  Positive
# 9   The blockchain ecosystem has rapidly evolved, ...         795  Positive
# 10  AI is flipping the script on software developm...        1716  Positive
# 11  Ensuring efficient, reliable, high-quality sof...        1350  Positive
# 12  GraalVM is an advanced JIT (Just-In-Time) comp...         516  Positive
# 13  What is the best basic template for an HTML do...         882  Positive
# 14  NetSuite offers various methods for authentica...         637  Positive
# 15   is a JavaScript charting library that allows ...         146  Positive
# 16  Meta Description: Learn about the power of col...         402  Positive
# 17  Input: head = [1,2,3,4,5]\nOutput: [5,4,3,2,1]...          34   Neutral
# 18  Input: head = [1,2,3,4,5]\nOutput: [5,4,3,2,1]...          34   Neutral
# 19  In the world of blockchain development, scalab...         624  Positive
# 20  Managing media on a WordPress site can quickly...         765  Positive
# 21  As a passionate Dungeons & Dragons player and ...         303  Positive
# 22  Hi devs, If you're new to Docker and trying to...         383  Positive
# 23  Test scripts are a set of instructions or proc...        3085  Positive
# 24  "You should write tests before you write the c...         695  Positive
# 25  This blog post is firstly published on my pers...         148  Positive
# 26  Email workflow automation takes over administr...        1210  Positive
# 27  As a modern-age web developer, JavaScript is a...         228  Positive
# 28  A chatbot is a type of software that mimics co...        1779  Positive
# 29  Structured Query Language\nIntroduction to SQL...         466  Positive
# 30  Previously in , we started with some javascrip...         408  Positive
# 31  Bismillaahirrahmaanirrahiim. Pernahkah kamu pe...         609  Positive
# 32  There is no need to write code for it. Yii alr...          31  Negative
# 33  Managing access control for your Amazon S3 buc...         188  Positive
# 34  OpenSauced is a company on a mission to empowe...         445  Positive
# 35  If you have a static website (e.g., built with...         111  Positive
# 36  Once upon a time in the vibrant land of Reacto...         218  Positive
# 37  This blog post summarizes my presentation deli...         248  Positive
# 38  Smoke testing made the job easy for many teste...        1141  Positive
# 39  Let's talk about routing in Nextjs. Today, we ...         341  Positive
# 40  When deciding which frontend framework to use,...         249  Positive
# 41   is a critical vulnerability in Jenkins that a...         360  Negative
# 42  Check out our latest blog on Creating a Synchr...          64  Positive
# 43  🚀 Ready to dive into the world of databases? 🚀...          99  Positive
# 44  What are Closures in Rust? A closure in Rust i...         112   Neutral
# 45  CRUD web apps, which let you Create, Read, Upd...         934  Positive
# 46  Dive into the latest and greatest projects fro...         209  Positive
# 47  In today’s competitive digital world, optimizi...         473  Positive
# 48  Golang shines in backend development, concurre...         214  Positive
# 49  In the world of concurrent systems, especially...         606  Positive
#
#     Compound Score
# 0          -0.3786
# 1          -0.9945
# 2           0.9942
# 3           0.9764
# 4           0.9957
# 5           0.9981
# 6           0.9989
# 7           0.9930
# 8           0.9997
# 9           0.9989
# 10          0.9998
# 11          0.9994
# 12          0.9957
# 13          0.9991
# 14          0.9981
# 15          0.9898
# 16          0.9963
# 17          0.0000
# 18          0.0000
# 19          0.9986
# 20          0.9987
# 21          0.9882
# 22          0.9536
# 23          0.9999
# 24          0.9965
# 25          0.4939
# 26          0.9998
# 27          0.9868
# 28          0.9997
# 29          0.9674
# 30          0.9829
# 31          0.8036
# 32         -0.1280
# 33          0.9753
# 34          0.9990
# 35          0.9445
# 36          0.9963
# 37          0.9733
# 38          0.9991
# 39          0.9923
# 40          0.9922
# 41         -0.9190
# 42          0.8481
# 43          0.8429
# 44          0.0498
# 45          0.9998
# 46          0.9924
# 47          0.9992
# 48          0.9814
# 49          0.9930

# %% [markdown]
# ## Detecting the Language of each Article Content

# %%
import pandas as pd
import langid
import pycountry


def detect_language(text):
    # Convert NaN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # Use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang

df['Language'] = df['Article Content'].apply(detect_language)
df['Language'] = df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)
df
# Out:
#                                                  Link  \
# 
# 41   Jenkins File Read Vulnerability - CVE-2024-23897  2024-10-01T08:13:10Z
# 42  Creating a synchronized store between main and...  2024-10-01T09:58:24Z
# 43  MongoDB made simple: a basic guide to get started  2024-10-01T09:52:58Z
# 44                         What are Closures in Rust?  2024-10-01T06:30:02Z
# 45      The Best Tools for Building CRUD Applications  2024-10-01T09:36:05Z
# 46  LabEx Trending: Implementing React Navigation ...  2024-10-01T09:32:58Z
# 47  How Does Angular SEO Work and Why Is It Import...  2024-10-01T09:34:08Z
# 48  Golang microservice modular architecture with ...  2024-10-01T09:22:27Z
# 49            Locking Mechanisms in High-Load Systems  2024-10-01T11:00:00Z
#
#                          Author  \
# 0                   Ben Halpern
# 1   Ingo Steinke, web developer
# 2                    Ayu Adiati
# 3                    Nevo David
# 4                  Abbey Perini
# 5                      Rob Race
# 6                   Jaime López
# 7            Hugo Ramon Pereira
# 8              Arindam Majumder
# 9              Asjad Ahmed Khan
# 10                   Astrodevil
# 11               Ibrahim Salami
# 12                    balrajOla
# 13               Matti Bar-Zeev
# 14       Otutu Chinedu Kingsley
# 15                    Vishwas R
# 16                mohamed Tayel
# 17                   Se-ok Jeon
# 18                   Se-ok Jeon
# 19                    Alex Roor
# 20               Sharon Yelenik
# 21                 Ramon Gebben
# 22               Daniel Azevedo
# 23                Nazneen Ahmad
# 24                 Jorjis Hasan
# 25                   EmreKanbay
# 26                  Ivan Djuric
# 27                    Rajon Dey
# 28                Kedjuprecious
# 29                  Kiregi Paul
# 30                  Michael Otu
# 31             محمد يزيد الصبري
# 32           Bellatreche Brahim
# 33           El Morjani Mohamed
# 34                        Lymah
# 35                        Geoff
# 36                Parnika-Gupta
# 37                 Romar Cablao
# 38                Steve Wortham
# 39               Sheraz Manzoor
# 40                    Ali Ahsan
# 41               Very Lazy Tech
# 42               T Sudhish Nair
# 43              mahugnon dousso
# 44             Francesco Ciulla
# 45                        SCAND
# 46                        Labby
# 47                        Parth
# 48                         Anze
# 49                  luminousmen
#
#                                                  Tags Reading Time  \
# 0                          #discuss#watercooler#jokes   1 min read
# 1                             #discuss#watercooler#ai   6 min read
# 2                           #opensource#hacktoberfest   6 min read
# 3             #webdev#javascript#programming#tutorial   4 min read
# 4                #techtalks#career#programming#devrel   5 min read
# 5                                 #rails#ruby#hotwire  13 min read
# 6               #microsoftgraph#powershell#sharepoint   8 min read
# 7                             #clerk#vue#react#nextjs   6 min read
# 8   #opensource#webdev#beginners#hacktoberfestchal...   7 min read
# 9                          #go#ethereum#cosmosdb#web3   5 min read
# 10                    #webdev#opensource#ai#beginners  13 min read
# 11                           #devops#sre#productivity  10 min read
# 12                   #java#webdev#learning#javascript   3 min read
# 13                                #webdev#html#coding   7 min read
# 14                  #webdev#laravel#netsuite#tutorial   8 min read
# 15             #canvasjs#datatables#javascript#charts   3 min read
# 16                #csharp#dotnet#programming#tutorial   4 min read
# 17                                                      1 min read
# 18                                                      1 min read
# 19        #webdev#programming#productivity#blockchain   3 min read
# 20     #wordpress#mediamanagement#medialibrary#webdev   5 min read
# 21                 #javascript#typescript#gamedev#dnd   2 min read
# 22                                                      4 min read
# 23  #testscenario#testscript#softwaretesting#testp...  16 min read
# 24                           #vite#jest#testing#react   4 min read
# 25                                                      2 min read
# 26                                                      8 min read
# 27  #7usefuljsprojects#vanillajs#javascript#jsproj...   3 min read
# 28           #beginners#javascript#geminiapi#learning  22 min read
# 29                                                      3 min read
# 30                     #javascript#api#beginners#node   9 min read
# 31             #middleware#routing#controller#laravel   4 min read
# 32                                                      1 min read
# 33                                    #devops#aws#cli   2 min read
# 34             #opensource#starsearch#contribution#ai   3 min read
# 35                           #webdev#html#website#web   2 min read
# 36                 #webdev#javascript#react#beginners   3 min read
# 37                     #aws#karpenter#awscommunityday   2 min read
# 38                   #testing#software#ai#programming  10 min read
# 39               #nextjs#webdev#typescript#javascript   3 min read
# 40                      #angular#react#vue#javascript   3 min read
# 41     #cybersecurity#exploit#vulnerabilities#jenkins   2 min read
# 42            #electron#javascript#webdev#programming   1 min read
# 43                      #database#datascience#mongodb   1 min read
# 44                #programming#opensource#rust#webdev   1 min read
# 45                          #crudapp#crudapps#webapps   5 min read
# 46                        #labex#programming#projects   2 min read
# 47                      #seo#angular#digitalmarketing   4 min read
# 48                                #webdev#go#tutorial   3 min read
# 49                 #concurrency#database#architecture   4 min read
#
#                                       Article Content  Word Count Sentiment  \
# 0   Meme Monday! Today's cover image comes from . ...          19  Negative
# 1   "Future workshop with AI," "creativity with AI...         782  Negative
# 2   It's that time of the year again: Hacktoberfes...         432  Positive
# 3   According to npmjs.com statistics, i18next is ...         538  Positive
# 4   Take it from someone who barely passed their c...         739  Positive
# 5   This article will explore Turbo 8's powerful f...        1338  Positive
# 6   Are you tired of the limitations of PowerShell...         697  Positive
# 7   INTRODUCTION Authentication is a very importan...         595  Positive
# 8   October is Almost Here—And So Are Some Epic Op...         929  Positive
# 9   The blockchain ecosystem has rapidly evolved, ...         795  Positive
# 10  AI is flipping the script on software developm...        1716  Positive
# 11  Ensuring efficient, reliable, high-quality sof...        1350  Positive
# 12  GraalVM is an advanced JIT (Just-In-Time) comp...         516  Positive
# 13  What is the best basic template for an HTML do...         882  Positive
# 14  NetSuite offers various methods for authentica...         637  Positive
# 15   is a JavaScript charting library that allows ...         146  Positive
# 16  Meta Description: Learn about the power of col...         402  Positive
# 17  Input: head = [1,2,3,4,5]\nOutput: [5,4,3,2,1]...          34   Neutral
# 18  Input: head = [1,2,3,4,5]\nOutput: [5,4,3,2,1]...          34   Neutral
# 19  In the world of blockchain development, scalab...         624  Positive
# 20  Managing media on a WordPress site can quickly...         765  Positive
# 21  As a passionate Dungeons & Dragons player and ...         303  Positive
# 22  Hi devs, If you're new to Docker and trying to...         383  Positive
# 23  Test scripts are a set of instructions or proc...        3085  Positive
# 24  "You should write tests before you write the c...         695  Positive
# 25  This blog post is firstly published on my pers...         148  Positive
# 26  Email workflow automation takes over administr...        1210  Positive
# 27  As a modern-age web developer, JavaScript is a...         228  Positive
# 28  A chatbot is a type of software that mimics co...        1779  Positive
# 29  Structured Query Language\nIntroduction to SQL...         466  Positive
# 30  Previously in , we started with some javascrip...         408  Positive
# 31  Bismillaahirrahmaanirrahiim. Pernahkah kamu pe...         609  Positive
# 32  There is no need to write code for it. Yii alr...          31  Negative
# 33  Managing access control for your Amazon S3 buc...         188  Positive
# 34  OpenSauced is a company on a mission to empowe...         445  Positive
# 35  If you have a static website (e.g., built with...         111  Positive
# 36  Once upon a time in the vibrant land of Reacto...         218  Positive
# 37  This blog post summarizes my presentation deli...         248  Positive
# 38  Smoke testing made the job easy for many teste...        1141  Positive
# 39  Let's talk about routing in Nextjs. Today, we ...         341  Positive
# 40  When deciding which frontend framework to use,...         249  Positive
# 41   is a critical vulnerability in Jenkins that a...         360  Negative
# 42  Check out our latest blog on Creating a Synchr...          64  Positive
# 43  🚀 Ready to dive into the world of databases? 🚀...          99  Positive
# 44  What are Closures in Rust? A closure in Rust i...         112   Neutral
# 45  CRUD web apps, which let you Create, Read, Upd...         934  Positive
# 46  Dive into the latest and greatest projects fro...         209  Positive
# 47  In today’s competitive digital world, optimizi...         473  Positive
# 48  Golang shines in backend development, concurre...         214  Positive
# 49  In the world of concurrent systems, especially...         606  Positive
#
#     Compound Score    Language
# 0          -0.3786     English
# 1          -0.9945     English
# 2           0.9942     English
# 3           0.9764     English
# 4           0.9957     English
# 5           0.9981     English
# 6           0.9989     English
# 7           0.9930     English
# 8           0.9997     English
# 9           0.9989     English
# 10          0.9998     English
# 11          0.9994     English
# 12          0.9957     English
# 13          0.9991     English
# 14          0.9981     English
# 15          0.9898     English
# 16          0.9963     English
# 17          0.0000     English
# 18          0.0000     English
# 19          0.9986     English
# 20          0.9987     English
# 21          0.9882     English
# 22          0.9536     English
# 23          0.9999     English
# 24          0.9965     English
# 25          0.4939     English
# 26          0.9998     English
# 27          0.9868     English
# 28          0.9997     English
# 29          0.9674     English
# 30          0.9829     English
# 31          0.8036  Indonesian
# 32         -0.1280     English
# 33          0.9753     English
# 34          0.9990     English
# 35          0.9445     English
# 36          0.9963     English
# 37          0.9733     English
# 38          0.9991     English
# 39          0.9923     English
# 40          0.9922     English
# 41         -0.9190     English
# 42          0.8481     English
# 43          0.8429     English
# 44          0.0498     English
# 45          0.9998     English
# 46          0.9924     English
# 47          0.9992     English
# 48          0.9814     English
# 49          0.9930     English

# %% [markdown]
# ## Testing for successful handshake

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://testtech:Your_password@cluster0.ahrx7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ## Moving our data to MongoDB Atlas

# %%
uri = "mongodb+srv://testtech:Your_password@cluster0.ahrx7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"


# Specify the database and collection
db = client['my_database']  # Create/use 'my_database'
collection = db['article_collection']  # Create/use 'my_collection'

# Convert DataFrame to dictionary (list of dictionaries)
data = df.to_dict(orient='records')

# Insert the data into the MongoDB collection
result = collection.insert_many(data)

# Print the inserted IDs
print("Inserted document IDs:", result.inserted_ids)



# Step 1: Identify duplicates
pipeline = [
    {
        "$group": {
            "_id": "$Link",  # Field to check for duplicates
            "uniqueIds": { "$addToSet": "$_id" },  # Store all unique _ids
            "count": { "$sum": 1 }  # Count duplicates
        }
    },
    {
        "$match": {
            "count": { "$gt": 1 }  # Only keep duplicates
        }
    }
]

duplicates = collection.aggregate(pipeline)

# Step 2: Remove duplicates
for doc in duplicates:
    unique_ids = doc['uniqueIds']
    unique_ids.pop(0)  # Keep the first id
    # Delete the duplicates
    collection.delete_many({"_id": {"$in": unique_ids}})

print("Duplicates removed.")
# Out:
# Inserted document IDs: [ObjectId('66fbe37cde36e73a61c0a1ab'), ObjectId('66fbe37cde36e73a61c0a1ac'), ObjectId('66fbe37cde36e73a61c0a1ad'), ObjectId('66fbe37cde36e73a61c0a1ae'), ObjectId('66fbe37cde36e73a61c0a1af'), ObjectId('66fbe37cde36e73a61c0a1b0'), ObjectId('66fbe37cde36e73a61c0a1b1'), ObjectId('66fbe37cde36e73a61c0a1b2'), ObjectId('66fbe37cde36e73a61c0a1b3'), ObjectId('66fbe37cde36e73a61c0a1b4'), ObjectId('66fbe37cde36e73a61c0a1b5'), ObjectId('66fbe37cde36e73a61c0a1b6'), ObjectId('66fbe37cde36e73a61c0a1b7'), ObjectId('66fbe37cde36e73a61c0a1b8'), ObjectId('66fbe37cde36e73a61c0a1b9'), ObjectId('66fbe37cde36e73a61c0a1ba'), ObjectId('66fbe37cde36e73a61c0a1bb'), ObjectId('66fbe37cde36e73a61c0a1bc'), ObjectId('66fbe37cde36e73a61c0a1bd'), ObjectId('66fbe37cde36e73a61c0a1be'), ObjectId('66fbe37cde36e73a61c0a1bf'), ObjectId('66fbe37cde36e73a61c0a1c0'), ObjectId('66fbe37cde36e73a61c0a1c1'), ObjectId('66fbe37cde36e73a61c0a1c2'), ObjectId('66fbe37cde36e73a61c0a1c3'), ObjectId('66fbe37cde36e73a61c0a1c4'), ObjectId('66fbe37cde36e73a61c0a1c5'), ObjectId('66fbe37cde36e73a61c0a1c6'), ObjectId('66fbe37cde36e73a61c0a1c7'), ObjectId('66fbe37cde36e73a61c0a1c8'), ObjectId('66fbe37cde36e73a61c0a1c9'), ObjectId('66fbe37cde36e73a61c0a1ca'), ObjectId('66fbe37cde36e73a61c0a1cb'), ObjectId('66fbe37cde36e73a61c0a1cc'), ObjectId('66fbe37cde36e73a61c0a1cd'), ObjectId('66fbe37cde36e73a61c0a1ce'), ObjectId('66fbe37cde36e73a61c0a1cf'), ObjectId('66fbe37cde36e73a61c0a1d0'), ObjectId('66fbe37cde36e73a61c0a1d1'), ObjectId('66fbe37cde36e73a61c0a1d2'), ObjectId('66fbe37cde36e73a61c0a1d3'), ObjectId('66fbe37cde36e73a61c0a1d4'), ObjectId('66fbe37cde36e73a61c0a1d5'), ObjectId('66fbe37cde36e73a61c0a1d6'), ObjectId('66fbe37cde36e73a61c0a1d7'), ObjectId('66fbe37cde36e73a61c0a1d8'), ObjectId('66fbe37cde36e73a61c0a1d9'), ObjectId('66fbe37cde36e73a61c0a1da'), ObjectId('66fbe37cde36e73a61c0a1db'), ObjectId('66fbe37cde36e73a61c0a1dc')]
# Duplicates removed.

# %%
import requests

def get_schools(api_key, location, radius=100000):
    endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    params = {
        'location': location,
        'radius': radius,
        'type': 'school',
        'key': api_key
    }
    
    response = requests.get(endpoint_url, params=params)
    
    results = response.json()['results']
    print(results)
    schools = []
    for place in results:
        schools.append({
            'name': place['name'],
            'address': place['vicinity'],
            'lat': place['geometry']['location']['lat'],
            'lng': place['geometry']['location']['lng']
        })
    
    return schools

# Usage
api_key = 'AIzaSyC0QJ7eoHROwGMk_3aF37wD-1Smc_snxbo'
location = '9.0820,8.6753'  # Example coordinates for Nigeria
schools = get_schools(api_key, location)

for school in schools:
    print(f"Name: {school['name']}")
    print(f"Address: {school['address']}")
    print(f"Coordinates: {school['lat']}, {school['lng']}")
    print("---")
# Out:
# [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.091788, 'lng': 8.674761999999998}, 'viewport': {'northeast': {'lat': 9.0925497802915, 'lng': 8.677422700000001}, 'southwest': {'lat': 9.089851819708496, 'lng': 8.673875099999995}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Ad-Dawatul Islamiyyah Islamic Books and Material store', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJq2qWMwnYUxARJz7YgcCRkTs', 'plus_code': {'compound_code': '3MRF+PW Angwana, Nigeria', 'global_code': '6FXC3MRF+PW'}, 'reference': 'ChIJq2qWMwnYUxARJz7YgcCRkTs', 'scope': 'GOOGLE', 'types': ['school', 'point_of_interest', 'establishment'], 'vicinity': 'Akinpelu Street'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 8.921756299999998, 'lng': 8.3691541}, 'viewport': {'northeast': {'lat': 8.922504030291503, 'lng': 8.370464230291502}, 'southwest': {'lat': 8.919806069708498, 'lng': 8.367766269708497}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Shepherds International College Akwanga', 'photos': [{'height': 2016, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109484977544130450215">KROMYON DAKAI</a>'], 'photo_reference': 'AdCG2DPpNx-L0wUzR2M-7c0AmLbQpNjL9QozT8oiGu16YHj9f8nwG45GJFaCvkwunPWi3g86umbLHk01b6KvjFhySwLIFFWOXWq9o1iZPkEKX6HA9lT74OZ7Pkwjizxwv4NkapCZOGUO_ABwoSrZUwRanjXzo034d40C3uhEUYiX5bffirDA', 'width': 4592}], 'place_id': 'ChIJq6qqqrqcURARaAQB7EyCC-8', 'rating': 4.3, 'reference': 'ChIJq6qqqrqcURARaAQB7EyCC-8', 'scope': 'GOOGLE', 'types': ['school', 'point_of_interest', 'establishment'], 'user_ratings_total': 4, 'vicinity': 'W9C9+PM2, Akwanga'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277}, 'viewport': {'northeast': {'lat': 9.083419830291504, 'lng': 8.676783630291503}, 'southwest': {'lat': 9.0807218697085, 'lng': 8.674085669708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Kim Standard Foundation Academy', 'place_id': 'ChIJSeXqNgBjURARxsG_UQztNzw', 'reference': 'ChIJSeXqNgBjURARxsG_UQztNzw', 'scope': 'GOOGLE', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'vicinity': '3MJG+Q4R, Nyibango'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277}, 'viewport': {'northeast': {'lat': 9.083419830291504, 'lng': 8.6767835802915}, 'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Najaona Science Academy Okefomo', 'place_id': 'ChIJNYH9HQBjURARUOD9Q_i8iXs', 'rating': 5, 'reference': 'ChIJNYH9HQBjURARUOD9Q_i8iXs', 'scope': 'GOOGLE', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': '3MJG+Q4R, Mama'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277}, 'viewport': {'northeast': {'lat': 9.083419830291504, 'lng': 8.6767835802915}, 'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Pride praise international school', 'place_id': 'ChIJCycZCwBjURARNX_gpysXz_M', 'reference': 'Ch ...
# Name: Ad-Dawatul Islamiyyah Islamic Books and Material store
# Address: Akinpelu Street
# Coordinates: 9.091788, 8.674761999999998
# ---
# Name: Shepherds International College Akwanga
# Address: W9C9+PM2, Akwanga
# Coordinates: 8.921756299999998, 8.3691541
# ---
# Name: Kim Standard Foundation Academy
# Address: 3MJG+Q4R, Nyibango
# Coordinates: 9.081999, 8.675277
# ---
# Name: Najaona Science Academy Okefomo
# Address: 3MJG+Q4R, Mama
# Coordinates: 9.081999, 8.675277
# ---
# Name: Pride praise international school
# Address: 3MJG+Q4R, Mama
# Coordinates: 9.081999, 8.675277
# ---
# Name: College of education zuba
# Address: 3MJG+Q4R, Mama
# Coordinates: 9.081999, 8.675277
# ---
# Name: Muhammad Auwal
# Address: 3MJG+Q4R, Mama
# Coordinates: 9.081999, 8.675277
# ---
# Name: Muazzam Bala
# Address: 3MJG+Q4R, Kwara
# Coordinates: 9.081999, 8.675277
# ---
# Name: Abubakar as-sadiq rimin hamza islamic, nur, pri, and secondary school. no.1492
# Address: 3MJG+Q4R, Mama
# Coordinates: 9.081999, 8.675277
# ---
# Name: Lagos Street Primary School
# Address: 12, By Cameroun Road, Kaduna
# Coordinates: 9.081999, 8.675277
# ---
# Name: Almadina International Islamic Academy
# Address: 38,Dd4 Ramat Close
# Coordinates: 9.081999, 8.675277
# ---
# Name: Bethel Best Centre
# Address: 7,Aso Pada Road Nasarawa Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---
# Name: Divine Daycare
# Address: 42,Aso Pada Road Karu Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---
# Name: The Incubators Academy
# Address: 45,Mission House Juji Village, Lagos
# Coordinates: 9.081999, 8.675277
# ---
# Name: De Cornerstone International Academy
# Address: 24,Aso C,Mararaba Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---
# Name: Migrant Fishermen Primary School
# Address: 7 Tolofa Village, Ovia South-West
# Coordinates: 9.081999, 8.675277
# ---
# Name: Dolphin Model School
# Address: 42,Aso Pada Road Karu Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---
# Name: Amazing Height International Academy
# Address: 33,Aso Pada Road Nasarawa Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---
# Name: Akinbo International School
# Address: Km 3 Abuja - Kaduna - Zaria Express Way, Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---
# Name: Divine Mercy Partnership Academy
# Address: 39,Aso Mararaba Nasarawa Nassarawa State
# Coordinates: 9.081999, 8.675277
# ---

# %%
import requests

# Your API key

# Define the Google Places API endpoint for nearby searches
endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Define parameters for your request
params = {
    'location': '9.0820,8.6753',  # Latitude and longitude for a location in Nigeria (Abuja example)
    'radius': 5000000,               # Search within a 5km radius
    'type': 'school',             # Type of place (school)
    'key': api_key                # Your API key
}

# Make the request to the Places API
response = requests.get(endpoint_url, params=params)
print(response.json())
# Parse the response
if response.status_code == 200:
    school_data = response.json()
    schools = school_data.get('results', [])
    
    # Print out details of the schools
    for school in schools:
        print(f"School Name: {school['name']}")
        print(f"Address: {school.get('vicinity', 'N/A')}")
        print(f"Location: {school['geometry']['location']}")
        print("-" * 40)
else:
    print("Failed to retrieve data:", response.status_code)
# Out:
# {'html_attributions': [], 'next_page_token': 'AdCG2DNValWnLmLqyTPV0aFPi0vXscKYM5W_mtVFSlLmwTqoOTu1Qma4BpDTXiS_nrdzdHTBXBy4foaP45TTDzTFr7ZzUWjI_HWCYeuFhyj00BG5BBfnOzkzmU0A9P8SbcdxCeqB-vzVBJZI0o4OhbUVzBf7PYiEWZpCwlgNWFSbyz4JCw98H2A-0mxg5efjqQ1txwggtsvyhs4ACggz3J3A7v9mwaMW1ISWieleooc79-d2-_NWIv18x1L-HiGFFJItS5rz1-q4C-nlu_9Ik_FvYmWruYIADM4-7gWP8A6HNJ3NoD9cow4Ubh9YkukzMHidxLQ0o1Bc13yIah1DBwka2rAR935nAnmeF_Qolrb2oj2tCfyZLxlaRK7kGRSdBZZD0X96YsIoOsuCFA1NfzVvIZRmopMlGQqU4L8TRiHFBsJ_e4aAceqoTwc', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.091788, 'lng': 8.674761999999998}, 'viewport': {'northeast': {'lat': 9.0925497802915, 'lng': 8.677422700000001}, 'southwest': {'lat': 9.089851819708496, 'lng': 8.673875099999995}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Ad-Dawatul Islamiyyah Islamic Books and Material store', 'opening_hours': {'open_now': False}, 'place_id': 'ChIJq2qWMwnYUxARJz7YgcCRkTs', 'plus_code': {'compound_code': '3MRF+PW Angwana, Nigeria', 'global_code': '6FXC3MRF+PW'}, 'reference': 'ChIJq2qWMwnYUxARJz7YgcCRkTs', 'scope': 'GOOGLE', 'types': ['school', 'point_of_interest', 'establishment'], 'vicinity': 'Akinpelu Street'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 8.921756299999998, 'lng': 8.3691541}, 'viewport': {'northeast': {'lat': 8.922504030291503, 'lng': 8.370464230291502}, 'southwest': {'lat': 8.919806069708498, 'lng': 8.367766269708497}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Shepherds International College Akwanga', 'photos': [{'height': 2016, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109484977544130450215">KROMYON DAKAI</a>'], 'photo_reference': 'AdCG2DMV9OexamCCGIyI92hei-W2x5u3SSzPu1t-r_ceqtWqXKtZRwJIko-uHqxD7pcY2fSKnc158EQ0mS8GpWVISTgA5JPjjNeS6M9BGih1bDFdMYGtrJ75lhi-X-_FM4w7nGDWWBrlNUvLJTaVF74gx667Wn3vRHrkLWGc3-0mxk7JH435', 'width': 4592}], 'place_id': 'ChIJq6qqqrqcURARaAQB7EyCC-8', 'rating': 4.3, 'reference': 'ChIJq6qqqrqcURARaAQB7EyCC-8', 'scope': 'GOOGLE', 'types': ['school', 'point_of_interest', 'establishment'], 'user_ratings_total': 4, 'vicinity': 'W9C9+PM2, Akwanga'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277}, 'viewport': {'northeast': {'lat': 9.083419830291504, 'lng': 8.676783630291503}, 'southwest': {'lat': 9.0807218697085, 'lng': 8.674085669708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Kim Standard Foundation Academy', 'place_id': 'ChIJSeXqNgBjURARxsG_UQztNzw', 'reference': 'ChIJSeXqNgBjURARxsG_UQztNzw', 'scope': 'GOOGLE', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'vicinity': '3MJG+Q4R, Nyibango'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277}, 'viewport': {'northeast': {'lat': 9.083419830291504, 'lng': 8.6767835802915}, 'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'icon_background_color': '#7B9EB0', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet', 'name': 'Najaona Science Academy Okefomo', 'place_id': 'ChIJNYH9HQBjURARUOD9Q_i8iXs', 'rating': 5, 'reference': 'ChIJNYH9HQBjURARUOD9Q_i8iXs', 'scope': 'GOOGLE', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': '3MJG+Q4R, Mama'}, {'business_status': 'OPERATIONAL', 'geometry': {'locati ...
# School Name: Ad-Dawatul Islamiyyah Islamic Books and Material store
# Address: Akinpelu Street
# Location: {'lat': 9.091788, 'lng': 8.674761999999998}
# ----------------------------------------
# School Name: Shepherds International College Akwanga
# Address: W9C9+PM2, Akwanga
# Location: {'lat': 8.921756299999998, 'lng': 8.3691541}
# ----------------------------------------
# School Name: Kim Standard Foundation Academy
# Address: 3MJG+Q4R, Nyibango
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Najaona Science Academy Okefomo
# Address: 3MJG+Q4R, Mama
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Pride praise international school
# Address: 3MJG+Q4R, Mama
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: College of education zuba
# Address: 3MJG+Q4R, Mama
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Muhammad Auwal
# Address: 3MJG+Q4R, Mama
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Muazzam Bala
# Address: 3MJG+Q4R, Kwara
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Abubakar as-sadiq rimin hamza islamic, nur, pri, and secondary school. no.1492
# Address: 3MJG+Q4R, Mama
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Lagos Street Primary School
# Address: 12, By Cameroun Road, Kaduna
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Almadina International Islamic Academy
# Address: 38,Dd4 Ramat Close
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Bethel Best Centre
# Address: 7,Aso Pada Road Nasarawa Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Divine Daycare
# Address: 42,Aso Pada Road Karu Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: The Incubators Academy
# Address: 45,Mission House Juji Village, Lagos
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: De Cornerstone International Academy
# Address: 24,Aso C,Mararaba Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Migrant Fishermen Primary School
# Address: 7 Tolofa Village, Ovia South-West
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Dolphin Model School
# Address: 42,Aso Pada Road Karu Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Amazing Height International Academy
# Address: 33,Aso Pada Road Nasarawa Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Akinbo International School
# Address: Km 3 Abuja - Kaduna - Zaria Express Way, Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------
# School Name: Divine Mercy Partnership Academy
# Address: 39,Aso Mararaba Nasarawa Nassarawa State
# Location: {'lat': 9.081999, 'lng': 8.675277}
# ----------------------------------------

# %%
school_data
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AdCG2DMqOFZ3YM4pGVPI8LJZlT4V4FvYjBHgRBQ0-wnqw5INw0S85V6mFsD0LFrZgrXNnpGtc7MoPTClknKyfWhqbHqOjEjHGdqlkNrf7kJWP9gauWxgDJ8yt6WEJZu2smGf7oBJGE7jAtWCDb-DwfVyQrEJZ9XY_rYwYQkPM7QA4Wcya7_hjx0ql7-HS_I0_vdOtd30rrRUL4f6KGDnALnFzaPZUYW28rRPV_c6zNQy44b0myiC4HjLwy0S97Vda0cGUWYG0ya9Y6gt9YFkSQkBs-xw1AKvQ22mx9ElD5FEXUSy5gbDYW5jzD5SQIAa9b61sYoHqCIUtuSL614CPq9Uv7-ckgWMgol49ClXmFujMOr7jc6o64FN9jYlAf75xL85nSXJQMyRvTXN9pmvqwf2MMmD16dLyajgxyM6sQ7lZQSggjyBnlMYF0k',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.091788, 'lng': 8.674761999999998},
#     'viewport': {'northeast': {'lat': 9.0925497802915,
#       'lng': 8.677422700000001},
#      'southwest': {'lat': 9.089851819708496, 'lng': 8.673875099999995}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Ad-Dawatul Islamiyyah Islamic Books and Material store',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJq2qWMwnYUxARJz7YgcCRkTs',
#    'plus_code': {'compound_code': '3MRF+PW Angwana, Nigeria',
#     'global_code': '6FXC3MRF+PW'},
#    'reference': 'ChIJq2qWMwnYUxARJz7YgcCRkTs',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'vicinity': 'Akinpelu Street'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277},
#     'viewport': {'northeast': {'lat': 9.083419830291504,
#       'lng': 8.676783630291503},
#      'southwest': {'lat': 9.0807218697085, 'lng': 8.674085669708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Kim Standard Foundation Academy',
#    'place_id': 'ChIJSeXqNgBjURARxsG_UQztNzw',
#    'reference': 'ChIJSeXqNgBjURARxsG_UQztNzw',
#    'scope': 'GOOGLE',
#    'types': ['primary_school', 'school', 'point_of_interest', 'establishment'],
#    'vicinity': '3MJG+Q4R, Nyibango'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277},
#     'viewport': {'northeast': {'lat': 9.083419830291504,
#       'lng': 8.6767835802915},
#      'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Najaona Science Academy Okefomo',
#    'place_id': 'ChIJNYH9HQBjURARUOD9Q_i8iXs',
#    'rating': 5,
#    'reference': 'ChIJNYH9HQBjURARUOD9Q_i8iXs',
#    'scope': 'GOOGLE',
#    'types': ['primary_school', 'school', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '3MJG+Q4R, Mama'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277},
#     'viewport': {'northeast': {'lat': 9.083419830291504,
#       'lng': 8.6767835802915},
#      'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Pride praise international school',
#    'place_id': 'ChIJCycZCwBjURARNX_gpysXz_M',
#    'reference': 'ChIJCycZCwBjURARNX_gpysXz_M',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'vicinity': '3MJG+Q4R, Mama'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277},
#     'viewport': {'northeast': {'lat': 9.083419830291504,
#       'lng': 8.6767835802915},
#      'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'College of education zuba',
#    'place_id': 'ChIJLyzC0xljURARk2QPXkFCbi0',
#    'rating': 5,
#    'reference': 'ChIJLyzC0xljURARk2QPXkFCbi0',
#    'scope': 'GOOGLE',
#    'types': ['secondary_school',
#     'school',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '3MJG+Q4R, Mama'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277},
#     'viewport': {'northeast': {'lat': 9.083419830291504,
#       'lng': 8.6767835802915},
#      'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Muhammad Auwal',
#    'place_id': 'ChIJW6qJX_pjURARvkJ92n2ZQKA',
#    'reference': 'ChIJW6qJX_pjURARvkJ92n2ZQKA',
#    'scope': 'GOOGLE',
#    'types': ['secondary_school',
#     'school',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': '3MJG+Q4R, Mama'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 9.081999, 'lng': 8.675277},
#     'viewport': {'northeast': {'lat': 9.083419830291504,
#       'lng': 8.6767835802915},
#      'southwest': {'lat': 9.0807218697085, 'lng': 8.674085619708496}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Muazzam Bala',
#    'place_id': 'ChIJdXTeBXxjURARN1UPdRs5gh8',
#    'reference': 'ChIJdXTeBXxjURARN1UPdRs5gh8',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'vicinity':