# %% [markdown]
# ### Import Libraries and Install

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd

# %% [markdown]
# ## Scraping dev.to

# %%
url = 'https://dev.to/'

ua = UserAgent()
userAgent = ua.random
headers = {'User-Agent': userAgent}
page = requests.get(url, headers = headers)
soup = BeautifulSoup(page.content, "html.parser")
print(url)
blog_box = soup.find_all('div', class_= "crayons-story")

links = []
titles = []
time_uploaded = []
authors = []
tags = []
reading_times = []

for box in blog_box:
    #links
    if box.find('h2', class_ = "crayons-story__title") is not None:
        link = box.find('h2', class_ = "crayons-story__title").a  #.replace('\n\t\t','').replace('\n','').strip()
        link = link['href']
        links.append(link)
    else:
        links.append('None')

    #titles
    if box.find('h2', class_ = "crayons-story__title") is not None:
        title = box.find('h2', class_ = "crayons-story__title").text.replace('\n','').strip()
        titles.append(title)
    else:
        titles.append('None')

    #time_uploaded
    if box.find('time', attrs={"datetime": True}) is not None:
        time_upload = box.find('time', attrs={"datetime": True})   #.replace('\n\t\t','').replace('\n','').strip()
        time_upload = time_upload['datetime']
        time_uploaded.append(time_upload)
    else:
        time_uploaded.append('None') 

    #author
    if box.find('a', class_ ="crayons-story__secondary fw-medium m:hidden") is not None:
        author = box.find('a', class_ ="crayons-story__secondary fw-medium m:hidden").text.replace('\n','').strip()
        authors.append(author)
    else:
        authors.append('None')

    #tags
    if box.find('div', class_ ="crayons-story__tags") is not None:
        tag = box.find('div', class_ ="crayons-story__tags").text.replace('\n','').strip()
        tags.append(tag)
    else:
        tags.append('None')

    #reading_time
    if box.find('div', class_ ="crayons-story__save") is not None:
        reading_time = box.find('div', class_ ="crayons-story__save").text.replace('\n','').strip()
        reading_times.append(reading_time)
    else:
        reading_times.append('None')

df = pd.DataFrame({
    'Link': links,
    'Title': titles,
    'Time Uploaded': time_uploaded,
    'Author': authors,
    'Tags': tags,
    'Reading Time': reading_times
})

df_cleaned = df[df['Link'] != 'None']

article = []
article_link = []
def get_full_content(url): 
    ua = UserAgent()
    userAgent = ua.random
    headers = {'User-Agent': userAgent}
    page = requests.get(url, headers = headers)
    soup = BeautifulSoup(page.content, "html.parser")
    print(url)
    content = soup.find('div', class_= "crayons-article__body text-styles spec__body")
    paragraphs = content.find_all('p')
    contents = []
    # Iterate over each <p> tag and remove any <a> tags within them
    for paragraph in paragraphs:
        for a in paragraph.find_all('a'):
            a.decompose()  # Removes <a> tag and its content

    # Print the cleaned text from each <p> tag
    for paragraph in paragraphs:
        contents.append(paragraph.get_text())

    string = ' '.join(contents)
    article.append(string)
    article_link.append(url)

for i in df_cleaned.Link:
    get_full_content(i)


article_df = pd.DataFrame({
    'Article Content': article,
    'Link': article_link
})


merged_df = pd.merge(df_cleaned, article_df, on='Link', how='inner')
merged_df
# Out:
# https://dev.to/
# https://dev.to/devteam/happy-11111101001-join-our-new-year-writing-challenge-43g4
# https://dev.to/sholajegede/part-2-master-authentication-and-role-based-access-control-rbac-with-kinde-and-convex-in-a-ch
# https://dev.to/jetthoughts/why-ai-hasnt-blown-our-mindsyet-1f7e
# https://dev.to/resource_bunk_1077cab07da/why-most-notion-templates-fail-businesses-and-how-to-create-ones-that-work-4jnd
# https://dev.to/0x3d_site/25-golang-resources-every-developer-will-find-helpful-and-interesting-1ooh
# https://dev.to/sonaykara/react-keeping-components-pure-32jn
# https://dev.to/lovestaco/building-a-login-component-with-ssr-support-using-solidjs-15oj
# https://dev.to/hanzla-baig/upcoming-challenges-on-devto-3434
# https://dev.to/kiraaziz/i-hate-website-builders-so-i-built-my-own-1728
# https://dev.to/makechi02/2024-a-year-of-resilience-learning-and-growth-5h3d
# https://dev.to/kcatucuamba/dominio-personalizado-en-amazon-api-gateway-dominio-desde-godaddy-cm1
# https://dev.to/eunit/five-advanced-techniques-to-improve-automated-testing-by-50-ccf
# https://dev.to/shrsv/price-wage-profit-rent-14p7
# https://dev.to/dhanushnehru/dev-retro-2024-journey-in-review-2i4d
# 46                         Laravel route alternatives  2025-01-04T20:36:13Z
# 47               AWS Lambda and Its Invocation Models  2025-01-04T15:32:21Z
# 48                                    Install Flutter  2025-01-04T18:36:03Z
# 49  Teaching Africa through AI, one language at a ...  2025-01-04T18:36:29Z
#
#                     Author                                               Tags  \
# 0                 Jess Lee       #devchallenge#newyearchallenge#career#future
# 1             Shola Jegede                      #kinde#convex#nextjs#tutorial
# 2          JetThoughts Dev
# 3            Resource Bunk                      #notion#beginners#tutorial#ai
# 4                0x3d Site                #go#google#programming#productivity
# 5               Sonay Kara               #webdev#javascript#programming#react
# 6    Athreya aka Maneshwar           #webdev#javascript#beginners#programming
# 7              Hanzla Baig  #agentai#githubchallenge#githubcopilot#devchal...
# 8                 kiraaziz                #electron#nextjs#tailwindcss#webdev
# 9                 Makechi™  #devchallenge#newyearchallenge#career#programming
# 10        Kevin Catucuamba                                       #aws#route53
# 11        Emmanuel Uchenna
# 12   Shrijith Venkatramana              #ai#management#programming#leadership
# 13               Dhanush N  #devchallenge#newyearchallenge#career#devresol...
# 14            Chirag Singh                 #node#nginx#javascript#programming
# 15            Steve Yonkeu                             #go#webdev#programming
# 16            Steve Yonkeu                                #go#dev#tech#webdev
# 17                   Athan                #webdev#javascript#programming#node
# 18            Kiran Baliga    #devchallenge#newyearchallenge#career#beginners
# 19                Dubjay18                                 #go#backend#webdev
# 20            Harsh Mishra                    #dbms#sql#mysql#computerscience
# 21          Alvaro Montoro                                        #opinion#ai
# 22                  Okerew                               #osxiec#docker#macos
# 23         younesHajizadeh
# 24            Said MOUNAIM           #webdev#javascript#programming#beginners
# 25          Alabi Temitope  #webdev#javascript#programming#softwaredevelop...
# 26               Ali Helmy                             #docusaurus#ai#rag#llm
# 27       Francisco Moretti                 #tailwindcss#vscode#tools#shadcnui
# 28              georgoulis                  #dataengineering#datascience#data
# 29                Dubjay18
# 30           pahlavaubivca
# 31                 Mikhail
# 32         Sebastian Pavel                     #laravel#nextjs#typescript#php
# 33                   rodbv
# 34          Madhav Ganesan
# 35           Vishal Shukla                           #webdev#go#docker#twilio
# 36             Keyul Patel                #cloudflare#domain#substack#writing
# 37           Sanath Shenoy            #blockchain#bitcoin#web3#cryptocurrency
# 38  Matt Ellen-Tsivintzeli              #devchallenge#newyearchallenge#career
# 39      Jose Maria Iriarte        #cpp#beginners#softwareengineering#learning
# 40                  Sourav                 #webdev#javascript#ai#productivity
# 41             Cheedge Lee                 #clusterip#nodeport#kubernetes#cka
# 42                  Sourav               #webdev#javascript#programming#react
# 43               Yen Colon
# 44        Aleksey Razbakov                    #ai#productivity#startup#webdev
# 45                AIRabbit
# 46        david duymelinck                                       #php#laravel
# 47             Emi Roberti                       #lambda#aws#serverless#cloud
# 48          Embatec Astelo              #webdev#programming#beginners#flutter
# 49                  Ndiaga                    #ai#education#opensource#africa
#
#    Reading Time                                    Article Content
# 0    3 min read  Happy New Year, everyone! Running through Febr...
# 1    7 min read  This is the Part 2 to this post:  In this guid...
# 2    3 min read  In a world buzzing with talk about artificial ...
# 3    3 min read  Notion templates have become an essential tool...
# 4   12 min read    Universal JSON, BSON, YAML, CSV, XML, mt940 ...
# 5    2 min read  If you like my articles, you can buy me a coff...
# 6    2 min read  At Hexmos, we needed a versatile login compone...
# 7    2 min read  Take flight with GitHub Copilot 🛫  Challenge S...
# 8    2 min read  Website builders should make life easier, but ...
# 9    2 min read  Reflecting on 2024, it’s clear that this year ...
# 10   4 min read  Cuando se implementan servicios utilizando Ama...
# 11   8 min read  Software developers must stay ahead in  nowada...
# 12   3 min read  I'm Shrijith Venkatrama, the founder of Hexmos...
# 13   3 min read  This is a submission for the : Retro’ing and D...
# 14   8 min read  In today's microservices architecture, reverse...
# 15   2 min read  In Go (golang), the fmt package provides sever...
# 16   2 min read  It has always been a challenge for me when wor...
# 17  15 min read  A look back at 2024 and a preview of the year ...
# 18   2 min read  This is a submission for the : Retro’ing and D...
# 19   2 min read  When building robust, efficient, and maintaina...
# 20   8 min read  Database Management Systems (DBMS) are an esse...
# 21   4 min read  A recurring thought when preparing articles on...
# 22   1 min read  Published a new version of my software osxiec,...
# 23   4 min read  As a developer, you may have found yourself as...
# 24   1 min read  Dev Next is a job platform built for developer...
# 25   2 min read  This week was all about mastering responsivene...
# 26   2 min read  In the ever-evolving world of documentation, D...
# 27   1 min read  When working with Tailwind CSS variables in VS...
# 28   1 min read  When I landed my first job in Data, I didn’t a...
# 29   3 min read  Error handling in Go is well known for its sim...
# 30   1 min read  Rare but pretty annoying error like:\n Appears...
# 31   2 min read   is a free code coverage library for Java, cre...
# 32   2 min read  Working with Next.js as the frontend and Larav...
# 33   4 min read  This is part 6 of a set of posts in which I am...
# 34   3 min read  It is a set of rules, specifications, and prot...
# 35   6 min read  Begin by creating a new folder for your projec...
# 36   3 min read  Happy New Year, fellow mentees 🎓! Last week, I...
# 37   4 min read  Proof of Work (PoW) is a fundamental consensus...
# 38   2 min read  This is a submission for the : Compiling 2025....
# 39   3 min read  In this article, I want to share the capstone ...
# 40   2 min read  As a developer, you're always on the lookout f...
# 41   2 min read  ClusterIP\n NodePort\n The Endpoints object (1...
# 42   2 min read  React 19 introduces powerful new features that...
# 43   3 min read  Recently, while experimenting with Spring Boot...
# 44   2 min read  I have worked every day since the musicality f...
# 45   3 min read  Let's face it, as developers we practically li...
# 46   2 min read  Earlier today I reacted on a post about , and ...
# 47   3 min read  AWS Lambda is one of the most versatile and ef...
# 48   1 min read  For months I started but failed to install Flu...
# 49   1 min read  Over the next 5 years, Ndiaga Ka, a Computer S...

# %% [markdown]
# ## Getting the Word Count, Sentiment and Polarity Score of the Article Content

# %%
from nltk.corpus import stopwords
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

df = merged_df
# Download the stopwords dataset
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')


def count_words_without_stopwords(text):
    if isinstance(text, (str, bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        return len(filtered_words)
    else:
        0

df['Word Count'] = df['Article Content'].apply(count_words_without_stopwords)


sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    sentiment_scores = sid.polarity_scores(row)
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
        sentiment = 'Positive'
    elif compound_score <= -0.05:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'

    return sentiment, compound_score

df[['Sentiment', 'Compound Score']] = df['Article Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))

df
# Out:
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                                  Link  \
# 
# 49  Teaching Africa through AI, one language at a ...  2025-01-04T18:36:29Z
#
#                     Author                                               Tags  \
# 0                 Jess Lee       #devchallenge#newyearchallenge#career#future
# 1             Shola Jegede                      #kinde#convex#nextjs#tutorial
# 2          JetThoughts Dev
# 3            Resource Bunk                      #notion#beginners#tutorial#ai
# 4                0x3d Site                #go#google#programming#productivity
# 5               Sonay Kara               #webdev#javascript#programming#react
# 6    Athreya aka Maneshwar           #webdev#javascript#beginners#programming
# 7              Hanzla Baig  #agentai#githubchallenge#githubcopilot#devchal...
# 8                 kiraaziz                #electron#nextjs#tailwindcss#webdev
# 9                 Makechi™  #devchallenge#newyearchallenge#career#programming
# 10        Kevin Catucuamba                                       #aws#route53
# 11        Emmanuel Uchenna
# 12   Shrijith Venkatramana              #ai#management#programming#leadership
# 13               Dhanush N  #devchallenge#newyearchallenge#career#devresol...
# 14            Chirag Singh                 #node#nginx#javascript#programming
# 15            Steve Yonkeu                             #go#webdev#programming
# 16            Steve Yonkeu                                #go#dev#tech#webdev
# 17                   Athan                #webdev#javascript#programming#node
# 18            Kiran Baliga    #devchallenge#newyearchallenge#career#beginners
# 19                Dubjay18                                 #go#backend#webdev
# 20            Harsh Mishra                    #dbms#sql#mysql#computerscience
# 21          Alvaro Montoro                                        #opinion#ai
# 22                  Okerew                               #osxiec#docker#macos
# 23         younesHajizadeh
# 24            Said MOUNAIM           #webdev#javascript#programming#beginners
# 25          Alabi Temitope  #webdev#javascript#programming#softwaredevelop...
# 26               Ali Helmy                             #docusaurus#ai#rag#llm
# 27       Francisco Moretti                 #tailwindcss#vscode#tools#shadcnui
# 28              georgoulis                  #dataengineering#datascience#data
# 29                Dubjay18
# 30           pahlavaubivca
# 31                 Mikhail
# 32         Sebastian Pavel                     #laravel#nextjs#typescript#php
# 33                   rodbv
# 34          Madhav Ganesan
# 35           Vishal Shukla                           #webdev#go#docker#twilio
# 36             Keyul Patel                #cloudflare#domain#substack#writing
# 37           Sanath Shenoy            #blockchain#bitcoin#web3#cryptocurrency
# 38  Matt Ellen-Tsivintzeli              #devchallenge#newyearchallenge#career
# 39      Jose Maria Iriarte        #cpp#beginners#softwareengineering#learning
# 40                  Sourav                 #webdev#javascript#ai#productivity
# 41             Cheedge Lee                 #clusterip#nodeport#kubernetes#cka
# 42                  Sourav               #webdev#javascript#programming#react
# 43               Yen Colon
# 44        Aleksey Razbakov                    #ai#productivity#startup#webdev
# 45                AIRabbit
# 46        david duymelinck                                       #php#laravel
# 47             Emi Roberti                       #lambda#aws#serverless#cloud
# 48          Embatec Astelo              #webdev#programming#beginners#flutter
# 49                  Ndiaga                    #ai#education#opensource#africa
#
#    Reading Time                                    Article Content  \
# 0    3 min read  Happy New Year, everyone! Running through Febr...
# 1    7 min read  This is the Part 2 to this post:  In this guid...
# 2    3 min read  In a world buzzing with talk about artificial ...
# 3    3 min read  Notion templates have become an essential tool...
# 4   12 min read    Universal JSON, BSON, YAML, CSV, XML, mt940 ...
# 5    2 min read  If you like my articles, you can buy me a coff...
# 6    2 min read  At Hexmos, we needed a versatile login compone...
# 7    2 min read  Take flight with GitHub Copilot 🛫  Challenge S...
# 8    2 min read  Website builders should make life easier, but ...
# 9    2 min read  Reflecting on 2024, it’s clear that this year ...
# 10   4 min read  Cuando se implementan servicios utilizando Ama...
# 11   8 min read  Software developers must stay ahead in  nowada...
# 12   3 min read  I'm Shrijith Venkatrama, the founder of Hexmos...
# 13   3 min read  This is a submission for the : Retro’ing and D...
# 14   8 min read  In today's microservices architecture, reverse...
# 15   2 min read  In Go (golang), the fmt package provides sever...
# 16   2 min read  It has always been a challenge for me when wor...
# 17  15 min read  A look back at 2024 and a preview of the year ...
# 18   2 min read  This is a submission for the : Retro’ing and D...
# 19   2 min read  When building robust, efficient, and maintaina...
# 20   8 min read  Database Management Systems (DBMS) are an esse...
# 21   4 min read  A recurring thought when preparing articles on...
# 22   1 min read  Published a new version of my software osxiec,...
# 23   4 min read  As a developer, you may have found yourself as...
# 24   1 min read  Dev Next is a job platform built for developer...
# 25   2 min read  This week was all about mastering responsivene...
# 26   2 min read  In the ever-evolving world of documentation, D...
# 27   1 min read  When working with Tailwind CSS variables in VS...
# 28   1 min read  When I landed my first job in Data, I didn’t a...
# 29   3 min read  Error handling in Go is well known for its sim...
# 30   1 min read  Rare but pretty annoying error like:\n Appears...
# 31   2 min read   is a free code coverage library for Java, cre...
# 32   2 min read  Working with Next.js as the frontend and Larav...
# 33   4 min read  This is part 6 of a set of posts in which I am...
# 34   3 min read  It is a set of rules, specifications, and prot...
# 35   6 min read  Begin by creating a new folder for your projec...
# 36   3 min read  Happy New Year, fellow mentees 🎓! Last week, I...
# 37   4 min read  Proof of Work (PoW) is a fundamental consensus...
# 38   2 min read  This is a submission for the : Compiling 2025....
# 39   3 min read  In this article, I want to share the capstone ...
# 40   2 min read  As a developer, you're always on the lookout f...
# 41   2 min read  ClusterIP\n NodePort\n The Endpoints object (1...
# 42   2 min read  React 19 introduces powerful new features that...
# 43   3 min read  Recently, while experimenting with Spring Boot...
# 44   2 min read  I have worked every day since the musicality f...
# 45   3 min read  Let's face it, as developers we practically li...
# 46   2 min read  Earlier today I reacted on a post about , and ...
# 47   3 min read  AWS Lambda is one of the most versatile and ef...
# 48   1 min read  For months I started but failed to install Flu...
# 49   1 min read  Over the next 5 years, Ndiaga Ka, a Computer S...
#
#     Word Count Sentiment  Compound Score
# 0          235  Positive          0.9972
# 1          670  Positive          0.9962
# 2          314  Positive          0.9900
# 3          264  Positive          0.9966
# 4          446  Positive          0.9875
# 5          214  Positive          0.9179
# 6          191  Positive          0.9716
# 7          177  Positive          0.9870
# 8          129  Positive          0.8045
# 9          286  Positive          0.9948
# 10         592  Positive          0.4767
# 11         667  Positive          0.9992
# 12         390  Positive          0.9987
# 13         436  Positive          0.9988
# 14         733  Positive          0.9983
# 15          72  Positive          0.4404
# 16         101  Positive          0.0772
# 17        1454  Positive          0.9998
# 18         343  Positive          0.9965
# 19         153  Positive          0.9349
# 20         427  Positive          0.9884
# 21         546  Positive          0.9682
# 22          12  Positive          0.4019
# 23         654  Positive          0.9994
# 24          85  Positive          0.8750
# 25          81  Positive          0.9669
# 26         210  Positive          0.9812
# 27          86  Positive          0.9184
# 28         117  Positive          0.9408
# 29         407  Negative         -0.3316
# 30          69  Negative         -0.8439
# 31          80  Positive          0.7506
# 32         145  Positive          0.9707
# 33         254  Negative         -0.7540
# 34         279  Positive          0.9312
# 35         305  Positive          0.9777
# 36         393  Positive          0.9993
# 37         765  Negative         -0.2459
# 38         169  Positive          0.9586
# 39         698  Positive          0.9968
# 40         235  Positive          0.9935
# 41          33   Neutral          0.0000
# 42         150  Positive          0.9772
# 43         221  Positive          0.9584
# 44         257  Positive          0.9927
# 45         239  Positive          0.9950
# 46         182  Positive          0.9368
# 47         526  Positive          0.9863
# 48          63  Negative         -0.8563
# 49          33   Neutral          0.0000

# %% [markdown]
# ## Detecting the Language of each Article Content

# %%
import pandas as pd
import langid
import pycountry


def detect_language(text):
    # Convert NaN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # Use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang

df['Language'] = df['Article Content'].apply(detect_language)
df['Language'] = df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)
df
# Out:
#                                                  Link  \
# 0   https://dev.to/devteam/happy-11111101001-join-...
# 1   https://dev.to/sholajegede/part-2-master-authe...
# 2   https://dev.to/jetthoughts/why-ai-hasnt-blown-...
# 3   https://dev.to/resource_bunk_1077cab07da/why-m...
# 4   https://dev.to/0x3d_site/25-golang-resources-e...
# 5   https://dev.to/sonaykara/react-keeping-compone...
# 6   https://dev.to/lovestaco/building-a-login-comp...
# 7   https://dev.to/hanzla-baig/upcoming-challenges...
# 8   https://dev.to/kiraaziz/i-hate-website-builder...
# 9   https://dev.to/makechi02/2024-a-year-of-resili...
# 10  https://dev.to/kcatucuamba/dominio-personaliza...
# 11  https://dev.to/eunit/five-advanced-techniques-...
# 12   https://dev.to/shrsv/price-wage-profit-rent-14p7
# 13  https://dev.to/dhanushnehru/dev-retro-2024-jou...
# 14  https://dev.to/chiragcodesweb/building-a-scala...
# 15  https://dev.to/yokwejuste/how-to-scan-in-golan...
# 16  https://dev.to/yokwejuste/how-to-print-in-gola...
# 17       https://dev.to/stdlib/2024-retrospective-pip
# 18  https://dev.to/kiran_baliga/retroing-and-debug...
# 19  https://dev.to/dubjay18/the-power-of-context-i...
# 20  https://dev.to/harshm03/introduction-to-databa...
# 21  https://dev.to/alvaromontoro/human-writing-in-...
# 22  https://dev.to/okerew/new-version-for-my-osxie...
# 23  https://dev.to/youneshajizadeh/unpacking-the-b...
# 24  https://dev.to/saidmounaim/dev-next-is-a-job-p...
# 25  https://dev.to/toptech5419/-week-11-of-100days...
# 26  https://dev.to/ahelmy/unlock-the-power-of-docu...
# 27  https://dev.to/franciscomoretti/color-highligh...
# 28  https://dev.to/georgoulis/what-kind-of-data-te...
# 29  https://dev.to/dubjay18/gos-must-pattern-strea...
# 30  https://dev.to/pahlavaubivca/rust-registry-err...
# 31  https://dev.to/mikhailepatko/how-to-implement-...
# 32  https://dev.to/zerk4/laravel-debugbar-for-next...
# 33  https://dev.to/rodbv/creating-a-to-do-app-with...
# 34  https://dev.to/madgan95/interface-standard-ove...
# 35  https://dev.to/vishaaxl/build-an-otp-based-aut...
# 36  https://dev.to/master_mentee/how-i-set-up-my-c...
# 31  How to implement JaCoCo in Kotlin + Spring Boo...  2025-01-04T09:12:47Z
# 32                       Laravel Debugbar for Next.js  2025-01-04T19:52:33Z
# 33  Creating a To-Do app with Django and HTMX, par...  2025-01-04T21:28:30Z
# 34                       Interface Standard: Overview  2025-01-04T15:21:34Z
# 35  Build an OTP-Based Authentication Server with ...  2025-01-04T19:42:43Z
# 36  How I Set Up My Custom Domain and Email for Su...  2025-01-04T19:25:10Z
# 37          Understanding Proof of Work in Blockchain  2025-01-04T19:16:26Z
# 38                         2025! What is it good for?  2025-01-04T21:08:54Z
# 39  First Steps in C++: An Introductory Capstone P...  2025-01-04T19:05:37Z
# 40  Mastering LangChain: Simplifying Complex Devel...  2025-01-04T19:08:23Z
# 41                             ClusterIP vs. NodePort  2025-01-04T19:06:32Z
# 42  React 19 Unleashed 🚀: New Features Every Devel...  2025-01-04T18:59:06Z
# 43  Understanding Spring Security: Building an Aut...  2025-01-04T18:56:54Z
# 44  My Journey with AI Agents: Revolutionizing WeD...  2025-01-04T18:16:44Z
# 45            Stop Repeating Terminal Command; Ask AI  2025-01-04T18:56:17Z
# 46                         Laravel route alternatives  2025-01-04T20:36:13Z
# 47               AWS Lambda and Its Invocation Models  2025-01-04T15:32:21Z
# 48                                    Install Flutter  2025-01-04T18:36:03Z
# 49  Teaching Africa through AI, one language at a ...  2025-01-04T18:36:29Z
#
#                     Author                                               Tags  \
# 0                 Jess Lee       #devchallenge#newyearchallenge#career#future
# 1             Shola Jegede                      #kinde#convex#nextjs#tutorial
# 2          JetThoughts Dev
# 3            Resource Bunk                      #notion#beginners#tutorial#ai
# 4                0x3d Site                #go#google#programming#productivity
# 5               Sonay Kara               #webdev#javascript#programming#react
# 6    Athreya aka Maneshwar           #webdev#javascript#beginners#programming
# 7              Hanzla Baig  #agentai#githubchallenge#githubcopilot#devchal...
# 8                 kiraaziz                #electron#nextjs#tailwindcss#webdev
# 9                 Makechi™  #devchallenge#newyearchallenge#career#programming
# 10        Kevin Catucuamba                                       #aws#route53
# 11        Emmanuel Uchenna
# 12   Shrijith Venkatramana              #ai#management#programming#leadership
# 13               Dhanush N  #devchallenge#newyearchallenge#career#devresol...
# 14            Chirag Singh                 #node#nginx#javascript#programming
# 15            Steve Yonkeu                             #go#webdev#programming
# 16            Steve Yonkeu                                #go#dev#tech#webdev
# 17                   Athan                #webdev#javascript#programming#node
# 18            Kiran Baliga    #devchallenge#newyearchallenge#career#beginners
# 19                Dubjay18                                 #go#backend#webdev
# 20            Harsh Mishra                    #dbms#sql#mysql#computerscience
# 21          Alvaro Montoro                                        #opinion#ai
# 22                  Okerew                               #osxiec#docker#macos
# 23         younesHajizadeh
# 24            Said MOUNAIM           #webdev#javascript#programming#beginners
# 25          Alabi Temitope  #webdev#javascript#programming#softwaredevelop...
# 26               Ali Helmy                             #docusaurus#ai#rag#llm
# 27       Francisco Moretti                 #tailwindcss#vscode#tools#shadcnui
# 28              georgoulis                  #dataengineering#datascience#data
# 29                Dubjay18
# 30           pahlavaubivca
# 31                 Mikhail
# 32         Sebastian Pavel                     #laravel#nextjs#typescript#php
# 33                   rodbv
# 34          Madhav Ganesan
# 35           Vishal Shukla                           #webdev#go#docker#twilio
# 36             Keyul Patel                #cloudflare#domain#substack#writing
# 37           Sanath Shenoy            #blockchain#bitcoin#web3#cryptocurrency
# 38  Matt Ellen-Tsivintzeli              #devchallenge#newyearchallenge#career
# 39      Jose Maria Iriarte        #cpp#beginners#softwareengineering#learning
# 40                  Sourav                 #webdev#javascript#ai#productivity
# 41             Cheedge Lee                 #clusterip#nodeport#kubernetes#cka
# 42                  Sourav               #webdev#javascript#programming#react
# 43               Yen Colon
# 44        Aleksey Razbakov                    #ai#productivity#startup#webdev
# 45                AIRabbit
# 46        david duymelinck                                       #php#laravel
# 47             Emi Roberti                       #lambda#aws#serverless#cloud
# 48          Embatec Astelo              #webdev#programming#beginners#flutter
# 49                  Ndiaga                    #ai#education#opensource#africa
#
#    Reading Time                                    Article Content  \
# 0    3 min read  Happy New Year, everyone! Running through Febr...
# 1    7 min read  This is the Part 2 to this post:  In this guid...
# 2    3 min read  In a world buzzing with talk about artificial ...
# 3    3 min read  Notion templates have become an essential tool...
# 4   12 min read    Universal JSON, BSON, YAML, CSV, XML, mt940 ...
# 5    2 min read  If you like my articles, you can buy me a coff...
# 6    2 min read  At Hexmos, we needed a versatile login compone...
# 7    2 min read  Take flight with GitHub Copilot 🛫  Challenge S...
# 8    2 min read  Website builders should make life easier, but ...
# 9    2 min read  Reflecting on 2024, it’s clear that this year ...
# 10   4 min read  Cuando se implementan servicios utilizando Ama...
# 11   8 min read  Software developers must stay ahead in  nowada...
# 12   3 min read  I'm Shrijith Venkatrama, the founder of Hexmos...
# 13   3 min read  This is a submission for the : Retro’ing and D...
# 14   8 min read  In today's microservices architecture, reverse...
# 15   2 min read  In Go (golang), the fmt package provides sever...
# 16   2 min read  It has always been a challenge for me when wor...
# 17  15 min read  A look back at 2024 and a preview of the year ...
# 18   2 min read  This is a submission for the : Retro’ing and D...
# 19   2 min read  When building robust, efficient, and maintaina...
# 20   8 min read  Database Management Systems (DBMS) are an esse...
# 21   4 min read  A recurring thought when preparing articles on...
# 22   1 min read  Published a new version of my software osxiec,...
# 23   4 min read  As a developer, you may have found yourself as...
# 24   1 min read  Dev Next is a job platform built for developer...
# 25   2 min read  This week was all about mastering responsivene...
# 26   2 min read  In the ever-evolving world of documentation, D...
# 27   1 min read  When working with Tailwind CSS variables in VS...
# 28   1 min read  When I landed my first job in Data, I didn’t a...
# 29   3 min read  Error handling in Go is well known for its sim...
# 30   1 min read  Rare but pretty annoying error like:\n Appears...
# 31   2 min read   is a free code coverage library for Java, cre...
# 32   2 min read  Working with Next.js as the frontend and Larav...
# 33   4 min read  This is part 6 of a set of posts in which I am...
# 34   3 min read  It is a set of rules, specifications, and prot...
# 35   6 min read  Begin by creating a new folder for your projec...
# 36   3 min read  Happy New Year, fellow mentees 🎓! Last week, I...
# 37   4 min read  Proof of Work (PoW) is a fundamental consensus...
# 38   2 min read  This is a submission for the : Compiling 2025....
# 39   3 min read  In this article, I want to share the capstone ...
# 40   2 min read  As a developer, you're always on the lookout f...
# 41   2 min read  ClusterIP\n NodePort\n The Endpoints object (1...
# 42   2 min read  React 19 introduces powerful new features that...
# 43   3 min read  Recently, while experimenting with Spring Boot...
# 44   2 min read  I have worked every day since the musicality f...
# 45   3 min read  Let's face it, as developers we practically li...
# 46   2 min read  Earlier today I reacted on a post about , and ...
# 47   3 min read  AWS Lambda is one of the most versatile and ef...
# 48   1 min read  For months I started but failed to install Flu...
# 49   1 min read  Over the next 5 years, Ndiaga Ka, a Computer S...
#
#     Word Count Sentiment  Compound Score Language
# 0          235  Positive          0.9972  English
# 1          670  Positive          0.9962  English
# 2          314  Positive          0.9900  English
# 3          264  Positive          0.9966  English
# 4          446  Positive          0.9875  English
# 5          214  Positive          0.9179  English
# 6          191  Positive          0.9716  English
# 7          177  Positive          0.9870  English
# 8          129  Positive          0.8045  English
# 9          286  Positive          0.9948  English
# 10         592  Positive          0.4767  Spanish
# 11         667  Positive          0.9992  English
# 12         390  Positive          0.9987  English
# 13         436  Positive          0.9988  English
# 14         733  Positive          0.9983  English
# 15          72  Positive          0.4404  English
# 16         101  Positive          0.0772  English
# 17        1454  Positive          0.9998  English
# 18         343  Positive          0.9965  English
# 19         153  Positive          0.9349  English
# 20         427  Positive          0.9884  English
# 21         546  Positive          0.9682  English
# 22          12  Positive          0.4019  English
# 23         654  Positive          0.9994  English
# 24          85  Positive          0.8750  English
# 25          81  Positive          0.9669  English
# 26         210  Positive          0.9812  English
# 27          86  Positive          0.9184  English
# 28         117  Positive          0.9408  English
# 29         407  Negative         -0.3316  English
# 30          69  Negative         -0.8439  English
# 31          80  Positive          0.7506  English
# 32         145  Positive          0.9707  English
# 33         254  Negative         -0.7540  English
# 34         279  Positive          0.9312  English
# 35         305  Positive          0.9777  English
# 36         393  Positive          0.9993  English
# 37         765  Negative         -0.2459  English
# 38         169  Positive          0.9586  English
# 39         698  Positive          0.9968  English
# 40         235  Positive          0.9935  English
# 41          33   Neutral          0.0000  English
# 42         150  Positive          0.9772  English
# 43         221  Positive          0.9584  English
# 44         257  Positive          0.9927  English
# 45         239  Positive          0.9950  English
# 46         182  Positive          0.9368  English
# 47         526  Positive          0.9863  English
# 48          63  Negative         -0.8563  English
# 49          33   Neutral          0.0000  English

# %% [markdown]
# ## Testing for successful handshake

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = os.environ['URI_KEY']

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ## Moving our data to MongoDB Atlas

# %%
uri = os.environ['URI_KEY']


# Specify the database and collection
db = client['my_database']  # Create/use 'my_database'
collection = db['article_collection']  # Create/use 'my_collection'

# Convert DataFrame to dictionary (list of dictionaries)
data = df.to_dict(orient='records')

# Insert the data into the MongoDB collection
result = collection.insert_many(data)

# Print the inserted IDs
print("Inserted document IDs:", result.inserted_ids)



# Step 1: Identify duplicates
pipeline = [
    {
        "$group": {
            "_id": "$Link",  # Field to check for duplicates
            "uniqueIds": { "$addToSet": "$_id" },  # Store all unique _ids
            "count": { "$sum": 1 }  # Count duplicates
        }
    },
    {
        "$match": {
            "count": { "$gt": 1 }  # Only keep duplicates
        }
    }
]

duplicates = collection.aggregate(pipeline)

# Step 2: Remove duplicates
for doc in duplicates:
    unique_ids = doc['uniqueIds']
    unique_ids.pop(0)  # Keep the first id
    # Delete the duplicates
    collection.delete_many({"_id": {"$in": unique_ids}})

print("Duplicates removed.")
# Out:
# Inserted document IDs: [ObjectId('671180b7c829e33e5b3d7c41'), ObjectId('671180b7c829e33e5b3d7c42'), ObjectId('671180b7c829e33e5b3d7c43'), ObjectId('671180b7c829e33e5b3d7c44'), ObjectId('671180b7c829e33e5b3d7c45'), ObjectId('671180b7c829e33e5b3d7c46'), ObjectId('671180b7c829e33e5b3d7c47'), ObjectId('671180b7c829e33e5b3d7c48'), ObjectId('671180b7c829e33e5b3d7c49'), ObjectId('671180b7c829e33e5b3d7c4a'), ObjectId('671180b7c829e33e5b3d7c4b'), ObjectId('671180b7c829e33e5b3d7c4c'), ObjectId('671180b7c829e33e5b3d7c4d'), ObjectId('671180b7c829e33e5b3d7c4e'), ObjectId('671180b7c829e33e5b3d7c4f'), ObjectId('671180b7c829e33e5b3d7c50'), ObjectId('671180b7c829e33e5b3d7c51'), ObjectId('671180b7c829e33e5b3d7c52'), ObjectId('671180b7c829e33e5b3d7c53'), ObjectId('671180b7c829e33e5b3d7c54'), ObjectId('671180b7c829e33e5b3d7c55'), ObjectId('671180b7c829e33e5b3d7c56'), ObjectId('671180b7c829e33e5b3d7c57'), ObjectId('671180b7c829e33e5b3d7c58'), ObjectId('671180b7c829e33e5b3d7c59'), ObjectId('671180b7c829e33e5b3d7c5a'), ObjectId('671180b7c829e33e5b3d7c5b'), ObjectId('671180b7c829e33e5b3d7c5c'), ObjectId('671180b7c829e33e5b3d7c5d'), ObjectId('671180b7c829e33e5b3d7c5e'), ObjectId('671180b7c829e33e5b3d7c5f'), ObjectId('671180b7c829e33e5b3d7c60'), ObjectId('671180b7c829e33e5b3d7c61'), ObjectId('671180b7c829e33e5b3d7c62'), ObjectId('671180b7c829e33e5b3d7c63'), ObjectId('671180b7c829e33e5b3d7c64'), ObjectId('671180b7c829e33e5b3d7c65'), ObjectId('671180b7c829e33e5b3d7c66'), ObjectId('671180b7c829e33e5b3d7c67'), ObjectId('671180b7c829e33e5b3d7c68'), ObjectId('671180b7c829e33e5b3d7c69'), ObjectId('671180b7c829e33e5b3d7c6a'), ObjectId('671180b7c829e33e5b3d7c6b'), ObjectId('671180b7c829e33e5b3d7c6c'), ObjectId('671180b7c829e33e5b3d7c6d'), ObjectId('671180b7c829e33e5b3d7c6e'), ObjectId('671180b7c829e33e5b3d7c6f'), ObjectId('671180b7c829e33e5b3d7c70'), ObjectId('671180b7c829e33e5b3d7c71'), ObjectId('671180b7c829e33e5b3d7c72')]
# Duplicates removed.

# %%
import streamlit as st
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
from nltk.corpus import stopwords
import nltk
from dotenv import load_dotenv
import os
load_dotenv()

# MongoDB connection details
uri = os.environ['URI_KEY']
client = MongoClient(uri, server_api=ServerApi('1'))
db = client['my_database']  # Create/use 'my_database'
collection = db['article_collection'] 

# Load MongoDB data
data = pd.DataFrame(list(collection.find()))

# %%
data
df = data[data['Author'].str.contains('Ivanha Paz', case=False, na=False)]

df

#min_word_count = int(df['Word Count'].min())
max_word_count = int(data['Word Count'].min())
max_word_count
# Out:
# 0
